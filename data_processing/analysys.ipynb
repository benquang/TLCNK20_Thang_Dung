# %%
import pandas as pd

pl_matches = pd.read_csv('pl_matches.csv')

pl_matches
# Out:
#       Match_Date                Home_Team  Home_Sh  Home_SoT  Home_Touches  \
# 0     2022-08-05           Crystal Palace       10         2           726
# 1     2022-08-06                   Fulham        8         2           474
# 2     2022-08-06        Tottenham Hotspur       18         8           709
# 3     2022-08-06         Newcastle United       23         9           634
# 4     2022-08-06             Leeds United       12         4           515
# ...          ...                      ...      ...       ...           ...
# 1895  2018-10-20  Wolverhampton Wanderers       10         1           557
# 1896  2018-10-20             Cardiff City       22         5           478
# 1897  2018-10-20        Huddersfield Town       13         1           705
# 1898  2018-10-21                  Everton       20         4           692
# 1899  2018-10-22                  Arsenal       19         6           853
#
# ...

# %% [markdown]
# Kiểm tra kiểu dữ liệu columns

# %%
pl_matches.dtypes
# Out:
# Match_Date                  object
# Home_Team                   object
# Home_Sh                      int64
# Home_SoT                     int64
# Home_Touches                 int64
# Home_Tkl                     int64
# Home_Int                     int64
# Home_Blocks                  int64
# Home_xG_Expected           float64
# Home_npxG_Expected         float64
# Home_SCA_SCA                 int64
# Home_GCA_SCA                 int64
# Home_Cmp_Passes              int64
# Home_Att_Passes              int64
# Home_Cmp_percent_Passes    float64
# Home_PrgP_Passes             int64
# Home_Carries_Carries         int64
# Home_PrgC_Carries            int64
# Home_Att_Take_Ons            int64
# Home_Succ_Take_Ons           int64
# Away_Team                   object
# Away_Sh                      int64
# Away_SoT                     int64
# Away_Touches                 int64
# Away_Tkl                     int64
# Away_Int                     int64
# Away_Blocks                  int64
# ...

# %%
##
pl_matches['Home_Sh'] = pl_matches['Home_Sh'].astype(float)
pl_matches['Home_SoT'] = pl_matches['Home_SoT'].astype(float)
pl_matches['Home_Touches'] = pl_matches['Home_Touches'].astype(float)
pl_matches['Home_Tkl'] = pl_matches['Home_Tkl'].astype(float)
pl_matches['Home_Int'] = pl_matches['Home_Int'].astype(float)
pl_matches['Home_Blocks'] = pl_matches['Home_Blocks'].astype(float)
pl_matches['Home_SCA_SCA'] = pl_matches['Home_SCA_SCA'].astype(float)
pl_matches['Home_GCA_SCA'] = pl_matches['Home_GCA_SCA'].astype(float)
pl_matches['Home_Cmp_Passes'] = pl_matches['Home_Cmp_Passes'].astype(float)
pl_matches['Home_Att_Passes'] = pl_matches['Home_Att_Passes'].astype(float)
pl_matches['Home_PrgP_Passes'] = pl_matches['Home_PrgP_Passes'].astype(float)
pl_matches['Home_Carries_Carries'] = pl_matches['Home_Carries_Carries'].astype(float)
pl_matches['Home_PrgC_Carries'] = pl_matches['Home_PrgC_Carries'].astype(float)
pl_matches['Home_Att_Take_Ons'] = pl_matches['Home_Att_Take_Ons'].astype(float)
pl_matches['Home_Succ_Take_Ons'] = pl_matches['Home_Succ_Take_Ons'].astype(float)

pl_matches['Away_Sh'] = pl_matches['Away_Sh'].astype(float)
pl_matches['Away_SoT'] = pl_matches['Away_SoT'].astype(float)
pl_matches['Away_Touches'] = pl_matches['Away_Touches'].astype(float)
pl_matches['Away_Tkl'] = pl_matches['Away_Tkl'].astype(float)
pl_matches['Away_Int'] = pl_matches['Away_Int'].astype(float)
pl_matches['Away_Blocks'] = pl_matches['Away_Blocks'].astype(float)
pl_matches['Away_SCA_SCA'] = pl_matches['Away_SCA_SCA'].astype(float)
pl_matches['Away_GCA_SCA'] = pl_matches['Away_GCA_SCA'].astype(float)
pl_matches['Away_Cmp_Passes'] = pl_matches['Away_Cmp_Passes'].astype(float)
pl_matches['Away_Att_Passes'] = pl_matches['Away_Att_Passes'].astype(float)
pl_matches['Away_PrgP_Passes'] = pl_matches['Away_PrgP_Passes'].astype(float)
pl_matches['Away_Carries_Carries'] = pl_matches['Away_Carries_Carries'].astype(float)
pl_matches['Away_PrgC_Carries'] = pl_matches['Away_PrgC_Carries'].astype(float)
pl_matches['Away_Att_Take_Ons'] = pl_matches['Away_Att_Take_Ons'].astype(float)
pl_matches['Away_Succ_Take_Ons'] = pl_matches['Away_Succ_Take_Ons'].astype(float)

pl_matches.dtypes
# Out:
# Match_Date                  object
# Home_Team                   object
# Home_Sh                    float64
# Home_SoT                   float64
# Home_Touches               float64
# Home_Tkl                   float64
# Home_Int                   float64
# Home_Blocks                float64
# Home_xG_Expected           float64
# Home_npxG_Expected         float64
# Home_SCA_SCA               float64
# Home_GCA_SCA               float64
# Home_Cmp_Passes            float64
# Home_Att_Passes            float64
# Home_Cmp_percent_Passes    float64
# Home_PrgP_Passes           float64
# Home_Carries_Carries       float64
# Home_PrgC_Carries          float64
# Home_Att_Take_Ons          float64
# Home_Succ_Take_Ons         float64
# Away_Team                   object
# Away_Sh                    float64
# Away_SoT                   float64
# Away_Touches               float64
# Away_Tkl                   float64
# Away_Int                   float64
# Away_Blocks                float64
# ...

# %% [markdown]
# Định dạng column Match_Date yyyy-mm-dd để sắp xếp các matches theo thời gian

# %%
pl_matches['Match_Date'] = pd.to_datetime(pl_matches['Match_Date'])

pl_matches['Match_Date']
# Out:
# 0      2022-08-05
# 1      2022-08-06
# 2      2022-08-06
# 3      2022-08-06
# 4      2022-08-06
#           ...
# 1895   2018-10-20
# 1896   2018-10-20
# 1897   2018-10-20
# 1898   2018-10-21
# 1899   2018-10-22
# Name: Match_Date, Length: 1900, dtype: datetime64[ns]

# %%
pl_matches_des = pl_matches.sort_values(by='Match_Date', ascending=False)

pl_matches_des
# Out:
#      Match_Date          Home_Team  Home_Sh  Home_SoT  Home_Touches  Home_Tkl  \
# 311  2023-05-28            Chelsea     22.0       4.0         742.0      21.0
# 319  2023-05-28          Brentford     11.0       4.0         451.0      17.0
# 310  2023-05-28     Crystal Palace     15.0       3.0         677.0      15.0
# 312  2023-05-28  Manchester United     21.0       8.0         619.0      19.0
# 313  2023-05-28            Arsenal     14.0       8.0         573.0      17.0
# ...         ...                ...      ...       ...           ...       ...
# 1525 2018-08-11  Huddersfield Town      6.0       1.0         519.0      25.0
# 1524 2018-08-11            Watford     19.0       5.0         566.0      18.0
# 1523 2018-08-11        Bournemouth     11.0       3.0         678.0      11.0
# 1522 2018-08-11             Fulham     15.0       6.0         847.0      27.0
# 1520 2018-08-10  Manchester United      7.0       5.0         648.0      26.0
#
# ...

# %%
pl_matches_des.to_csv('descending.csv',index=False)

# %% [markdown]
# Thay tất cả statistics team bằng trung bình cộng của 2 trận của team trước đó

# %%
pl_matches_new = pl_matches_des

for i in range(0, len(pl_matches_new)):
    #lấy 2 trận gần nhất => count = 4
    home_count = 0
    away_count = 0

    #18 list ứng với 18 thuộc tính
    home_list1 = []
    home_list2 = []
    home_list3 = []
    home_list4 = []
    home_list5 = []
    home_list6 = []
    home_list7 = []
    home_list8 = []
    home_list9 = []
    home_list10 = []
    home_list11 = []
    home_list12 = []
    home_list13 = []
    home_list14 = []
    home_list15 = []
    home_list16 = []
    home_list17 = []
    home_list18 = []

    away_list1 = []
    away_list2 = []
    away_list3 = []
    away_list4 = []
    away_list5 = []
    away_list6 = []
    away_list7 = []
    away_list8 = []
    away_list9 = []
    away_list10 = []
    away_list11 = []
    away_list12 = []
    away_list13 = []
    away_list14 = []
    away_list15 = []
    away_list16 = []
    away_list17 = []
    away_list18 = []

    #dành cho home team
    for k in range(i+1, len(pl_matches_new)):

        if(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Team')] ==  pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Team')]):
            #
            home_list1.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Sh')])
            home_list2.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_SoT')])
            home_list3.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Touches')])
            home_list4.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Tkl')])
            home_list5.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Int')])
            home_list6.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Blocks')])
            home_list7.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_xG_Expected')])
            home_list8.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_npxG_Expected')])
            home_list9.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_SCA_SCA')])
            home_list10.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_GCA_SCA')])
            home_list11.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Cmp_Passes')])
            home_list12.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Att_Passes')])
            home_list13.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Cmp_percent_Passes')])
            home_list14.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_PrgP_Passes')])
            home_list15.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Carries_Carries')])
            home_list16.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_PrgC_Carries')])
            home_list17.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Att_Take_Ons')])
            home_list18.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Succ_Take_Ons')])

            home_count = home_count + 1
            if(home_count == 2):
                break

        if(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Team')] ==  pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Team')]):
            #
            home_list1.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Sh')])
            home_list2.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_SoT')])
            home_list3.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Touches')])
            home_list4.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Tkl')])
            home_list5.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Int')])
            home_list6.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Blocks')])
            home_list7.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_xG_Expected')])
            home_list8.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_npxG_Expected')])
            home_list9.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_SCA_SCA')])
            home_list10.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_GCA_SCA')])
            home_list11.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Cmp_Passes')])
            home_list12.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Att_Passes')])
            home_list13.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Cmp_percent_Passes')])
            home_list14.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_PrgP_Passes')])
            home_list15.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Carries_Carries')])
            home_list16.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_PrgC_Carries')])
            home_list17.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Att_Take_Ons')])
            home_list18.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Succ_Take_Ons')])

            home_count = home_count + 1
            if(home_count == 2):
                break

    #dành cho away team
    for j in range(i+1, len(pl_matches_new)):
        
        if(pl_matches_new.iloc[j, pl_matches_new.columns.get_loc('Home_Team')] ==  pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Team')]):
            #
            away_list1.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Sh')])
            away_list2.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_SoT')])
            away_list3.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Touches')])
            away_list4.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Tkl')])
            away_list5.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Int')])
            away_list6.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Blocks')])
            away_list7.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_xG_Expected')])
            away_list8.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_npxG_Expected')])
            away_list9.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_SCA_SCA')])
            away_list10.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_GCA_SCA')])
            away_list11.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Cmp_Passes')])
            away_list12.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Att_Passes')])
            away_list13.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Cmp_percent_Passes')])
            away_list14.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_PrgP_Passes')])
            away_list15.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Carries_Carries')])
            away_list16.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_PrgC_Carries')])
            away_list17.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Att_Take_Ons')])
            away_list18.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Home_Succ_Take_Ons')])

            away_count = away_count + 1
            if(away_count == 2):
                break

        if(pl_matches_new.iloc[j, pl_matches_new.columns.get_loc('Away_Team')] ==  pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Team')]):
            #
            away_list1.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Sh')])
            away_list2.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_SoT')])
            away_list3.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Touches')])
            away_list4.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Tkl')])
            away_list5.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Int')])
            away_list6.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Blocks')])
            away_list7.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_xG_Expected')])
            away_list8.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_npxG_Expected')])
            away_list9.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_SCA_SCA')])
            away_list10.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_GCA_SCA')])
            away_list11.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Cmp_Passes')])
            away_list12.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Att_Passes')])
            away_list13.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Cmp_percent_Passes')])
            away_list14.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_PrgP_Passes')])
            away_list15.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Carries_Carries')])
            away_list16.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_PrgC_Carries')])
            away_list17.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Att_Take_Ons')])
            away_list18.append(pl_matches_new.iloc[k, pl_matches_new.columns.get_loc('Away_Succ_Take_Ons')])

            away_count = away_count + 1
            if(away_count == 2):
                break
    
    #nếu ko có giá trị của 1 trong 2 team ở 2 trận trước đó thì ko cập nhật (vẫn giữ chỉ số cũ)
    if(len(home_list1) == 0 or len(away_list1) == 0): 
        continue
    #print(home_sh_list, sum(home_sh_list) / len(home_sh_list))
    #print(away_sh_list, sum(away_sh_list) / len(away_sh_list))
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Sh')] = sum(home_list1) / len(home_list1)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_SoT')] = sum(home_list2) / len(home_list2)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Touches')] = sum(home_list3) / len(home_list3)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Tkl')] = sum(home_list4) / len(home_list4)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Int')] = sum(home_list5) / len(home_list5)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Blocks')] = sum(home_list6) / len(home_list6)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_xG_Expected')] = sum(home_list7) / len(home_list7)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_npxG_Expected')] = sum(home_list8) / len(home_list8)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_SCA_SCA')] = sum(home_list9) / len(home_list9)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_GCA_SCA')] = sum(home_list10) / len(home_list10)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Cmp_Passes')] = sum(home_list11) / len(home_list11)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Att_Passes')] = sum(home_list12) / len(home_list12)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Cmp_percent_Passes')] = sum(home_list13) / len(home_list13)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_PrgP_Passes')] = sum(home_list14) / len(home_list14)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Carries_Carries')] = sum(home_list15) / len(home_list15)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_PrgC_Carries')] = sum(home_list16) / len(home_list16)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Att_Take_Ons')] = sum(home_list17) / len(home_list1)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Home_Succ_Take_Ons')] = sum(home_list18) / len(home_list18)


    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Sh')] = sum(away_list1) / len(away_list1)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_SoT')] = sum(away_list2) / len(away_list2)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Touches')] = sum(away_list3) / len(away_list3)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Tkl')] = sum(away_list4) / len(away_list4)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Int')] = sum(away_list5) / len(away_list5)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Blocks')] = sum(away_list6) / len(away_list6)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_xG_Expected')] = sum(away_list7) / len(away_list7)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_npxG_Expected')] = sum(away_list8) / len(away_list8)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_SCA_SCA')] = sum(away_list9) / len(away_list9)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_GCA_SCA')] = sum(away_list10) / len(away_list10)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Cmp_Passes')] = sum(away_list11) / len(away_list11)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Att_Passes')] = sum(away_list12) / len(away_list12)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Cmp_percent_Passes')] = sum(away_list13) / len(away_list13)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_PrgP_Passes')] = sum(away_list14) / len(away_list14)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Carries_Carries')] = sum(away_list15) / len(away_list15)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_PrgC_Carries')] = sum(away_list16) / len(away_list16)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Att_Take_Ons')] = sum(away_list17) / len(away_list17)
    pl_matches_new.iloc[i, pl_matches_new.columns.get_loc('Away_Succ_Take_Ons')] = sum(away_list18) / len(away_list18)

# %%
pl_matches_new.iloc[:,[pl_matches_new.columns.get_loc('Home_Team'), pl_matches_new.columns.get_loc('Home_Sh'),
                       pl_matches_new.columns.get_loc('Away_Team'), pl_matches_new.columns.get_loc('Away_Sh')]]

# %%
pl_matches_new.to_csv('pl_matches_modified.csv', index=False)
